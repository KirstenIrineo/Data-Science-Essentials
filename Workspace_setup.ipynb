# %% [markdown]
# <a href="https://colab.research.google.com/github/KirstenIrineo/Data-Science-Essentials/blob/main/Workspace_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Setting up your workspace**
#
# This includes isntallation, authentication of accounts, and configuration for us to start our data science journey
#
# 1.   Setting up Anaconda
# 2.   Setting up Github

# %% [markdown]
# **Installing Anaconda**
#
# 1. Open your internet browser, and search for Anaconda Download. Click on the first link (https://www.anaconda.com/download)
#
# 2. Download by either signing in/or signing up for an account
